# %%
import serial

# %%
with serial.Serial("COM5", 115200, bytesize=8, parity='N', stopbits=1,timeout=0.1) as ser:
    ser.dtr = True
    #ser.write(0xAD)
    #ser.write(0x00)
    for i in range(10):
        ser.write(0x00)
    ser.write(0x01)
    print(ser.read(2))
    for i in range(10):
        ser.write(0x00)
    ser.write(0x52)    
    ser.write(0x00)    
    ser.write(0x52)   
    ser.write(0x0F)   
    print(ser.read(2))
    #ser.write("?ECR\r\n".encode())
    #print(ser.readline())
    #print(ser.readline())
# Out:
# b''
# b''

# %%
00 00 00 00 00 00 00 00 00 00 01
17 0C                                              ..

00 00 00 00 00 00 00 00 00 00 52 00 52 0F         ..........R.R.
09 90                                              .

# %%
from IPython.core.display import display, HTML
with open("pyrometer_serial_log.txt", "r", encoding='utf16') as f:
    lines  = f.readlines()
    for line in lines:
        a = line.split('\t')
        if "IRP_MJ_WRITE" in line:
            display(HTML('<span style="color:red;">{}</span>'.format(a[6])))
        elif "IRP_MJ_READ" in line:
            display(HTML('<span style="color:green;">{}</span>'.format(a[6])))
# Out:
# <span style="color:red;">00 00 00 00 00 00 00 00 00 00 </span>
# <span style="color:red;">01 </span>
# <span style="color:green;">17 0c </span>
# <span style="color:red;">00 00 00 00 00 00 00 00 00 00 52 00 52 </span>
# <span style="color:red;">0f </span>
# <span style="color:green;">09 90 </span>
# <span style="color:red;">0f </span>
# <span style="color:green;">09 90 </span>
# <span style="color:red;">45 </span>
# <span style="color:green;">04 a7 17 0c 52 08 </span>
# <span style="color:red;">42 00 42 </span>
# <span style="color:green;">00 03 </span>
# <span style="color:red;">04 </span>
# <span style="color:green;">02 bc </span>
# <span style="color:red;">05 </span>
# <span style="color:green;">03 e8 </span>
# <span style="color:red;">0a </span>
# <span style="color:green;">23 28 </span>
# <span style="color:red;">0b </span>
# <span style="color:green;">3a 98 </span>
# <span style="color:red;">0c </span>
# <span style="color:green;">06 40 </span>
# ...

# %%
lines
# Out:
# ['00000000\t2018-08-28 09:24:59.4750627\t\tPnP Event: Connect\tDOWN\t0x00000000\t5c 00 3f 00 3f 00 5c 00 46 00 54 00 44 00 49 00 42 00 55 00 …\t\\.?.?.\\.F.T.D.I.B.U.…\n',
#  '00000001\t2018-08-28 09:25:06.4746699\t+6.9996072\tIRP_MJ_CREATE - process 7764 (CompactConnect.exe)\tDOWN\t0x00000000\t\t\n',
#  '00000002\t2018-08-28 09:25:06.4787462\t+0.0040763\tIRP_MJ_CREATE\tUP\t0x00000000\t\t\n',
#  "00000003\t2018-08-28 09:25:06.4787644\t+0.0000182\tIRP_MJ_DEVICECONTROL: IOCTL_SERIAL_SET_QUEUE_SIZE\tDOWN\t0x00000000\t10 27 00 00 00 04 00 00 \t.'......\n",
#  '00000004\t2018-08-28 09:25:06.4787681\t+0.0000037\tIRP_MJ_DEVICECONTROL: IOCTL_SERIAL_SET_QUEUE_SIZE\tUP\t0x00000000\t\t\n',
#  '00000013\t2018-08-28 09:25:06.4787826\t+0.0000034\tIRP_MJ_DEVICECONTROL: IOCTL_SERIAL_SET_BAUD_RATE\tDOWN\t0x00000000\t00 c2 01 00 \t....\n',
#  '00000014\t2018-08-28 09:25:06.4789823\t+0.0001997\tIRP_MJ_DEVICECONTROL: IOCTL_SERIAL_SET_BAUD_RATE\tUP\t0x00000000\t\t\n',
# ...

# %%
lines[21].split('\t')
# Out:
# ['00000035',
#  '2018-08-28 09:25:06.4800274',
#  '+0.0000060',
#  'IRP_MJ_WRITE',
#  'DOWN',
#  '0x00000000',
#  '00 00 00 00 00 00 00 00 00 00 ',
#  '..........\n']

# %%
with serial.Serial("COM5", 115200, bytesize=8, parity='N', stopbits=1,timeout=0.1) as ser:
    ser.write(b"\x2d")
    print([hex(x) for x in list(ser.read(100))])
# Out:
# ['0x1']

# %%
hex(8042862)
# Out:
# '0x7ab96e'

# %%
def read_temp():
    ser.write(b"\x01")
    x = ser.read(2)
    return 0.1*(x[0]*0xFF + x[1] - 1000)

# %%
with serial.Serial("COM5", 115200, bytesize=8, parity='N', stopbits=1,timeout=0.1) as ser:
    print(read_temp())
    print(read_temp())
    print(read_temp())
# Out:
# 487.70000000000005
# 487.70000000000005
# 487.70000000000005
